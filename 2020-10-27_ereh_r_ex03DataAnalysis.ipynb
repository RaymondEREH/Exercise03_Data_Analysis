# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('file.txt')

x = data[:]
y = data[:]
plt.grid(color='black', linestyle='-.', linewidth=0.7)
plt.title("Accelerator Department Data Analysis")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.plot(x, y,'r--', c='C4')
plt.show()

# %%
files=open('file.txt')
tet = files.read()
print(tet)
files.close()
# Out:
# 2.309570000000000078e+01
# 2.199320000000000164e+01
# 2.170210000000000150e+01
# 2.201170000000000115e+01
# 2.177439999999999998e+01
# 2.176170000000000115e+01
# 2.197360000000000113e+01
# 2.174800000000000111e+01
# 2.139260000000000161e+01
# 2.185060000000000002e+01
# 2.135549999999999926e+01
# 2.105570000000000164e+01
# 2.050199999999999889e+01
# 2.007130000000000081e+01
# 1.985060000000000002e+01
# 2.008200000000000074e+01
# 2.002339999999999876e+01
# 1.970700000000000074e+01
# 2.034669999999999845e+01
# 1.988090000000000046e+01
# 2.006540000000000035e+01
# 2.067869999999999919e+01
# 2.132519999999999882e+01
# 2.132519999999999882e+01
# 2.196189999999999998e+01
# 2.133889999999999887e+01
# 2.091700000000000159e+01
# 1.979489999999999839e+01
# 1.897850000000000037e+01
# 1.847269999999999968e+01
# 1.836329999999999885e+01
# 1.810249999999999915e+01
# 1.837209999999999965e+01
# 1.809469999999999956e+01
# 1.835940000000000083e+01
# 1.830470000000000041e+01
# 1.829589999999999961e+01
# ...
